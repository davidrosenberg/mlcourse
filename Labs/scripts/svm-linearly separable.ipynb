# %%
import matplotlib.pyplot as plt
import random
import numpy as np
# %matplotlib inline
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica'],'weight':'heavy','size':'12'})
rc('text', usetex=True)

# %%
x1 = np.random.normal(5, 1.75, 100)
x2 = np.random.normal(-5, 1.1, 100)
y1 = np.random.normal(5, 15, 100)
y2 = np.random.normal(-5, 15, 100)

# %%
plt.scatter(x1, y1, color = 'b')
plt.scatter(x2, y2, color = 'r')
plt.title("Linearly separable data")
plt.ylim(-60, 60)

#PATHFIG = "/Users/leventsagun/Dropbox/Apps/ShareLaTeX/mlcourse-labs/figures/"
#plt.savefig(PATHFIG + "SVM_data.pdf", layout = "tight")

x = np.linspace(1, -2)
y = np.linspace(-43, 43)
plt.plot(x, y, color = 'black')

x = np.linspace(-1, 0)
y = np.linspace(-43, 43)
plt.plot(x, y, color = 'black')

#PATHFIG = "/Users/leventsagun/Dropbox/Apps/ShareLaTeX/mlcourse-labs/figures/"
#plt.savefig(PATHFIG + "SVM_data_lines.pdf", layout = "tight")

plt.show()

# %%
plt.scatter(x1, y1, color = 'b')
plt.scatter(x2, y2, color = 'r')
plt.title("Linearly separable data")
plt.ylim(-60, 60)

x = np.linspace(1, -2)
y = np.linspace(-43, 43)
plt.plot(x, y, color = 'black')

x = np.linspace(-1, -1)
y = np.linspace(-43, 43)
plt.plot(x, y, color = 'black')

x = np.linspace(-3.25, 1.5)
y = np.linspace(-43, 43)
plt.plot(x, y, color = 'black')

x = np.linspace(1.5, -3.5)
y = np.linspace(-43, 43)
plt.plot(x, y, color = 'black')

PATHFIG = "/Users/leventsagun/Dropbox/Apps/ShareLaTeX/mlcourse-labs/figures/"
plt.savefig(PATHFIG + "SVM_data_morelines.pdf", layout = "tight")

plt.show()

# %%
plt.scatter(x1[0], y1[0], color='b')
#plt.scatter(0, 0, color = 'r')
plt.ylim(-60, 60)
plt.xlim(-10, 15)

x = np.linspace(1.5, -3.5)
y = np.linspace(-43, 43)
# emph points
plt.scatter(x[40], y[40], color='r')
plt.plot(x, y, color='black')

# green dotted line
vec1x = np.linspace(x[40], x1[0])
vec1y = np.linspace(y[40], y1[0])
plt.plot(vec1x, vec1y, 'g--')

# red dotted line
vec1x = np.linspace(x[13], x1[0])
vec1y = np.linspace(y[13], y1[0])
plt.plot(vec1x, vec1y, 'r--')

plt.annotate('x', (x1[0]+1, y1[0]))
plt.annotate("x'", (x[40], y[40]+4))
plt.annotate('$L$', (x[0]+0.2, y[0]))

plt.title("Distance of $x$ to $L$")
point = (x1[0], y1[0])

PATHFIG = "/Users/LeVent/Dropbox (Personal)/Apps/ShareLaTeX/mlcourse-labs/figures/"
plt.savefig(PATHFIG + "proj.pdf", layout = "tight")

# %%
len(x)
# Out:
# 50

# %%
plt.plot?
